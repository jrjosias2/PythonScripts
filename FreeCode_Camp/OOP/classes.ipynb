# %%
class User:
    pass 

josias = User()

josias.Name = 'Josias Leonardo Junior'
josias.RG = '41.611.881-1'
josias.CEP = '04304-110'
josias.Profession = 'Data Architect'
josias.Education = 'MBA'

jc = User()
jc.Name = 'Julio Cesar Ferraz Leonardo'
jc.Profession = 'TOTVS Architect'
jc.Education = 'Bachelor Administration'



print(josias.Name, josias.RG, josias.CEP, josias.__class__.__name__)
print(jc.Name, jc.Profession, jc.__class__.__name__)
# Out:
# Josias Leonardo Junior 41.611.881-1 04304-110 User
# Julio Cesar Ferraz Leonardo TOTVS Architect User

# %%
import datetime
from datetime import date

class User_Full:
    """
    Class User full created in order to deliver Customer object for this example on which bla bla bla
    The comentary above is called Docstring that have the goal of deliver a brief description and documentation for the class
    Please provide the birthday date with the following standard DD/MM/YYYY
    """
    def __init__(self, first_name, last_name, birthday, birth_country, birth_city):
        self.first_name = first_name
        self.last_name = last_name
        self.birthday = birthday
        self.birth_country = birth_country
        self.birth_city = birth_city
    
    def age(self):
        """Return the user's age in years"""
        today = date.today()
        date_test = f'{self.birthday[6:10], self.birthday[3:5], self.birthday[0:2]}'
        return int((today - (datetime.date(int(self.birthday[6:10]), int(self.birthday[3:5]), int(self.birthday[0:2])))).days / 365)

# %%
help(User_Full)

# %%
j2 = User_Full('Josias', 'Leonardo Junior', '25/10/1983', 'Brazil', 'Santos-SP')

j2.age()
# Out:
# 39
